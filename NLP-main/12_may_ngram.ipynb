# %%
text = """The climate has continuously changing for centuries. The global warming happens because the natural rotation of the sun that changes the intensity of sunlight and moving closer to the earth. Another cause of global warming is greenhouse gases. Greenhouse gases are carbon monoxide and sulphur dioxide it trap the solar heats rays and prevent it from escaping from the surface of the earth. This has cause the temperature of the earth increase. Volcanic eruptions are another issue that causes global warming. For instance, a single volcanic eruption will release amount of carbon dioxide and ash to the atmosphere. Once carbon dioxide increase, the temperature of earth increase and greenhouse trap the solar radiations in the earth. Finally, methane is another issue that causes global warming. Methane is also a greenhouse gas. Methane is more effective in trapping heat in the atmosphere that carbon dioxide by 20 times. Usually methane gas can release from many areas. For instance, it can be from cattle, landfill, natural gas, petroleum systems, coal mining, mobile explosion, or industrial waste process."""

# %%
text
# Out:
# 'The climate has continuously changing for centuries. The global warming happens because the natural rotation of the sun that changes the intensity of sunlight and moving closer to the earth. Another cause of global warming is greenhouse gases. Greenhouse gases are carbon monoxide and sulphur dioxide it trap the solar heats rays and prevent it from escaping from the surface of the earth. This has cause the temperature of the earth increase. Volcanic eruptions are another issue that causes global warming. For instance, a single volcanic eruption will release amount of carbon dioxide and ash to the atmosphere. Once carbon dioxide increase, the temperature of earth increase and greenhouse trap the solar radiations in the earth. Finally, methane is another issue that causes global warming. Methane is also a greenhouse gas. Methane is more effective in trapping heat in the atmosphere that carbon dioxide by 20 times. Usually methane gas can release from many areas. For instance, it can be from cattle, landfill, natural gas, petroleum systems, coal mining, mobile explosion, or industrial waste process.'

# %%
import random
import nltk
import numpy as np

# %%
n = 6

# %%
ngrams = {}

# %%
words = nltk.word_tokenize(text)

# %%
words
# Out:
# ['The',
#  'climate',
#  'has',
#  'continuously',
#  'changing',
#  'for',
#  'centuries',
#  '.',
#  'The',
#  'global',
#  'warming',
#  'happens',
#  'because',
#  'the',
#  'natural',
#  'rotation',
#  'of',
#  'the',
#  'sun',
#  'that',
#  'changes',
#  'the',
#  'intensity',
#  'of',
#  'sunlight',
#  'and',
#  'moving',
#  'closer',
#  'to',
#  'the',
#  'earth',
#  '.',
#  'Another',
#  'cause',
#  'of',
#  'global',
#  'warming',
#  'is',
#  'greenhouse',
#  'gases',
#  '.',
#  'Greenhouse',
#  'gases',
#  'are',
#  'carbon',
#  'monoxide',
#  'and',
#  'sulphur',
#  'dioxide',
#  'it',
#  'trap',
#  'the',
#  'solar',
#  'heats',
#  'rays',
#  'and',
#  'prevent',
#  'it',
#  'from',
#  'escaping',
#  'from',
#  'the',
#  'surface',
#  'of',
#  'the',
#  'earth',
#  '.',
#  'This',
#  'has',
#  'cause',
#  'the',
#  'temperature',
#  'of',
#  'the',
#  'earth',
#  'increase',
#  '.',
#  'Volcanic',
#  'eruptions',
#  'are',
#  'another',
#  'issue',
#  'that',
#  'causes',
#  'global',
#  'warming',
#  '.',
#  'For',
#  'instance',
#  ',',
#  'a',
#  'single',
#  'volcanic',
#  'eruption',
#  'will',
#  'release',
#  'amount',
#  'of',
#  'carbon',
#  'dioxide',
#  'and',
#  'ash',
#  'to',
#  'the',
#  'atmosphere',
#  '.',
#  'Once',
#  'carbon',
#  'dioxide',
#  'increase',
#  ',',
#  'the',
#  'temperature',
#  'of',
#  'earth',
#  'increase',
#  'and',
#  'greenhouse',
#  'trap',
#  'the',
#  'solar',
#  'radiations',
#  'in',
#  'the',
#  'earth',
#  '.',
#  'Finally',
#  ',',
#  'methane',
#  'is',
#  'another',
#  'issue',
#  'that',
#  'causes',
#  'global',
#  'warming',
#  '.',
#  'Methane',
#  'is',
#  'also',
#  'a',
#  'greenhouse',
#  'gas',
#  '.',
#  'Methane',
#  'is',
#  'more',
#  'effective',
#  'in',
#  'trapping',
#  'heat',
#  'in',
#  'the',
#  'atmosphere',
#  'that',
#  'carbon',
#  'dioxide',
#  'by',
#  '20',
#  'times',
#  '.',
#  'Usually',
#  'methane',
#  'gas',
#  'can',
#  'release',
#  'from',
#  'many',
#  'areas',
#  '.',
#  'For',
#  'instance',
#  ',',
#  'it',
#  'can',
#  'be',
#  'from',
#  'cattle',
#  ',',
#  'landfill',
#  ',',
#  'natural',
#  'gas',
#  ',',
#  'petroleum',
#  'systems',
#  ',',
#  'coal',
#  'mining',
#  ',',
#  'mobile',
#  'explosion',
#  ',',
#  'or',
#  'industrial',
#  'waste',
#  'process',
#  '.']

# %%
for i in range(len(words)-n):
    gram = ' '.join(words[i:i+n])
    if gram not in ngrams.keys():
        ngrams[gram] = []
    ngrams[gram].append(words[i+n])

# %%
ngrams
# Out:
# {'The climate has continuously changing for': ['centuries'],
#  'climate has continuously changing for centuries': ['.'],
#  'has continuously changing for centuries .': ['The'],
#  'continuously changing for centuries . The': ['global'],
#  'changing for centuries . The global': ['warming'],
#  'for centuries . The global warming': ['happens'],
#  'centuries . The global warming happens': ['because'],
#  '. The global warming happens because': ['the'],
#  'The global warming happens because the': ['natural'],
#  'global warming happens because the natural': ['rotation'],
#  'warming happens because the natural rotation': ['of'],
#  'happens because the natural rotation of': ['the'],
#  'because the natural rotation of the': ['sun'],
#  'the natural rotation of the sun': ['that'],
#  'natural rotation of the sun that': ['changes'],
#  'rotation of the sun that changes': ['the'],
#  'of the sun that changes the': ['intensity'],
#  'the sun that changes the intensity': ['of'],
#  'sun that changes the intensity of': ['sunlight'],
#  'that changes the intensity of sunlight': ['and'],
#  'changes the intensity of sunlight and': ['moving'],
#  'the intensity of sunlight and moving': ['closer'],
#  'intensity of sunlight and moving closer': ['to'],
#  'of sunlight and moving closer to': ['the'],
#  'sunlight and moving closer to the': ['earth'],
#  'and moving closer to the earth': ['.'],
#  'moving closer to the earth .': ['Another'],
#  'closer to the earth . Another': ['cause'],
#  'to the earth . Another cause': ['of'],
#  'the earth . Another cause of': ['global'],
#  'earth . Another cause of global': ['warming'],
#  '. Another cause of global warming': ['is'],
#  'Another cause of global warming is': ['greenhouse'],
#  'cause of global warming is greenhouse': ['gases'],
#  'of global warming is greenhouse gases': ['.'],
#  'global warming is greenhouse gases .': ['Greenhouse'],
#  'warming is greenhouse gases . Greenhouse': ['gases'],
#  'is greenhouse gases . Greenhouse gases': ['are'],
#  'greenhouse gases . Greenhouse gases are': ['carbon'],
#  'gases . Greenhouse gases are carbon': ['monoxide'],
#  '. Greenhouse gases are carbon monoxide': ['and'],
#  'Greenhouse gases are carbon monoxide and': ['sulphur'],
#  'gases are carbon monoxide and sulphur': ['dioxide'],
#  'are carbon monoxide and sulphur dioxide': ['it'],
#  'carbon monoxide and sulphur dioxide it': ['trap'],
#  'monoxide and sulphur dioxide it trap': ['the'],
#  'and sulphur dioxide it trap the': ['solar'],
#  'sulphur dioxide it trap the solar': ['heats'],
#  'dioxide it trap the solar heats': ['rays'],
#  'it trap the solar heats rays': ['and'],
#  'trap the solar heats rays and': ['prevent'],
#  'the solar heats rays and prevent': ['it'],
#  'solar heats rays and prevent it': ['from'],
#  'heats rays and prevent it from': ['escaping'],
#  'rays and prevent it from escaping': ['from'],
#  'and prevent it from escaping from': ['the'],
#  'prevent it from escaping from the': ['surface'],
#  'it from escaping from the surface': ['of'],
#  'from escaping from the surface of': ['the'],
#  'escaping from the surface of the': ['earth'],
#  'from the surface of the earth': ['.'],
#  'the surface of the earth .': ['This'],
#  'surface of the earth . This': ['has'],
#  'of the earth . This has': ['cause'],
#  'the earth . This has cause': ['the'],
#  'earth . This has cause the': ['temperature'],
#  '. This has cause the temperature': ['of'],
#  'This has cause the temperature of': ['the'],
#  'has cause the temperature of the': ['earth'],
#  'cause the temperature of the earth': ['increase'],
#  'the temperature of the earth increase': ['.'],
#  'temperature of the earth increase .': ['Volcanic'],
#  'of the earth increase . Volcanic': ['eruptions'],
#  'the earth increase . Volcanic eruptions': ['are'],
#  'earth increase . Volcanic eruptions are': ['another'],
#  'increase . Volcanic eruptions are another': ['issue'],
#  '. Volcanic eruptions are another issue': ['that'],
#  'Volcanic eruptions are another issue that': ['causes'],
#  'eruptions are another issue that causes': ['global'],
#  'are another issue that causes global': ['warming'],
#  'another issue that causes global warming': ['.', '.'],
#  'issue that causes global warming .': ['For', 'Methane'],
#  'that causes global warming . For': ['instance'],
#  'causes global warming . For instance': [','],
#  'global warming . For instance ,': ['a'],
#  'warming . For instance , a': ['single'],
#  '. For instance , a single': ['volcanic'],
#  'For instance , a single volcanic': ['eruption'],
#  'instance , a single volcanic eruption': ['will'],
#  ', a single volcanic eruption will': ['release'],
#  'a single volcanic eruption will release': ['amount'],
#  'single volcanic eruption will release amount': ['of'],
#  'volcanic eruption will release amount of': ['carbon'],
#  'eruption will release amount of carbon': ['dioxide'],
#  'will release amount of carbon dioxide': ['and'],
#  'release amount of carbon dioxide and': ['ash'],
#  'amount of carbon dioxide and ash': ['to'],
#  'of carbon dioxide and ash to': ['the'],
#  'carbon dioxide and ash to the': ['atmosphere'],
#  'dioxide and ash to the atmosphere': ['.'],
#  'and ash to the atmosphere .': ['Once'],
#  'ash to the atmosphere . Once': ['carbon'],
#  'to the atmosphere . Once carbon': ['dioxide'],
#  'the atmosphere . Once carbon dioxide': ['increase'],
#  'atmosphere . Once carbon dioxide increase': [','],
#  '. Once carbon dioxide increase ,': ['the'],
#  'Once carbon dioxide increase , the': ['temperature'],
#  'carbon dioxide increase , the temperature': ['of'],
#  'dioxide increase , the temperature of': ['earth'],
#  'increase , the temperature of earth': ['increase'],
#  ', the temperature of earth increase': ['and'],
#  'the temperature of earth increase and': ['greenhouse'],
#  'temperature of earth increase and greenhouse': ['trap'],
#  'of earth increase and greenhouse trap': ['the'],
#  'earth increase and greenhouse trap the': ['solar'],
#  'increase and greenhouse trap the solar': ['radiations'],
#  'and greenhouse trap the solar radiations': ['in'],
#  'greenhouse trap the solar radiations in': ['the'],
#  'trap the solar radiations in the': ['earth'],
#  'the solar radiations in the earth': ['.'],
#  'solar radiations in the earth .': ['Finally'],
#  'radiations in the earth . Finally': [','],
#  'in the earth . Finally ,': ['methane'],
#  'the earth . Finally , methane': ['is'],
#  'earth . Finally , methane is': ['another'],
#  '. Finally , methane is another': ['issue'],
#  'Finally , methane is another issue': ['that'],
#  ', methane is another issue that': ['causes'],
#  'methane is another issue that causes': ['global'],
#  'is another issue that causes global': ['warming'],
#  'that causes global warming . Methane': ['is'],
#  'causes global warming . Methane is': ['also'],
#  'global warming . Methane is also': ['a'],
#  'warming . Methane is also a': ['greenhouse'],
#  '. Methane is also a greenhouse': ['gas'],
#  'Methane is also a greenhouse gas': ['.'],
#  'is also a greenhouse gas .': ['Methane'],
#  'also a greenhouse gas . Methane': ['is'],
#  'a greenhouse gas . Methane is': ['more'],
#  'greenhouse gas . Methane is more': ['effective'],
#  'gas . Methane is more effective': ['in'],
#  '. Methane is more effective in': ['trapping'],
#  'Methane is more effective in trapping': ['heat'],
#  'is more effective in trapping heat': ['in'],
#  'more effective in trapping heat in': ['the'],
#  'effective in trapping heat in the': ['atmosphere'],
#  'in trapping heat in the atmosphere': ['that'],
#  'trapping heat in the atmosphere that': ['carbon'],
#  'heat in the atmosphere that carbon': ['dioxide'],
#  'in the atmosphere that carbon dioxide': ['by'],
#  'the atmosphere that carbon dioxide by': ['20'],
#  'atmosphere that carbon dioxide by 20': ['times'],
#  'that carbon dioxide by 20 times': ['.'],
#  'carbon dioxide by 20 times .': ['Usually'],
#  'dioxide by 20 times . Usually': ['methane'],
#  'by 20 times . Usually methane': ['gas'],
#  '20 times . Usually methane gas': ['can'],
#  'times . Usually methane gas can': ['release'],
#  '. Usually methane gas can release': ['from'],
#  'Usually methane gas can release from': ['many'],
#  'methane gas can release from many': ['areas'],
#  'gas can release from many areas': ['.'],
#  'can release from many areas .': ['For'],
#  'release from many areas . For': ['instance'],
#  'from many areas . For instance': [','],
#  'many areas . For instance ,': ['it'],
#  'areas . For instance , it': ['can'],
#  '. For instance , it can': ['be'],
#  'For instance , it can be': ['from'],
#  'instance , it can be from': ['cattle'],
#  ', it can be from cattle': [','],
#  'it can be from cattle ,': ['landfill'],
#  'can be from cattle , landfill': [','],
#  'be from cattle , landfill ,': ['natural'],
#  'from cattle , landfill , natural': ['gas'],
#  'cattle , landfill , natural gas': [','],
#  ', landfill , natural gas ,': ['petroleum'],
#  'landfill , natural gas , petroleum': ['systems'],
#  ', natural gas , petroleum systems': [','],
#  'natural gas , petroleum systems ,': ['coal'],
#  'gas , petroleum systems , coal': ['mining'],
#  ', petroleum systems , coal mining': [','],
#  'petroleum systems , coal mining ,': ['mobile'],
#  'systems , coal mining , mobile': ['explosion'],
#  ', coal mining , mobile explosion': [','],
#  'coal mining , mobile explosion ,': ['or'],
#  'mining , mobile explosion , or': ['industrial'],
#  ', mobile explosion , or industrial': ['waste'],
#  'mobile explosion , or industrial waste': ['process'],
#  'explosion , or industrial waste process': ['.']}

# %%
currentGram = ' '.join(words[0:n])

# %%
currentGram
# Out:
# 'The climate has continuously changing for'

# %%
result = currentGram
for i in range(50):
    if currentGram not in ngrams.keys():
        break
    possibilities = ngrams[currentGram]
    nextItem = possibilities[random.randrange(len(possibilities))]
    result += ' '+nextItem
    rword = nltk.word_tokenize(result)
    currentGram = ' '.join(rword[len(rword)-n:len(rword)])
print(result)
# Out:
# The climate has continuously changing for centuries . The global warming happens because the natural rotation of the sun that changes the intensity of sunlight and moving closer to the earth . Another cause of global warming is greenhouse gases . Greenhouse gases are carbon monoxide and sulphur dioxide it trap the solar heats rays and
